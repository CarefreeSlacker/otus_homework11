# %%
# Простые НС и метод обратного распространения ошибки
# 1. Реализовать полносвязную сеть: два скрытых слоя с функцией активации ReLU, на выходе softmax по количеству классов (задается как параметр).
# 2. Обучить НС на модельный датасет "make_moons" из skelarn. Визуализировать разделяющую поверхность.
# 3. Обучить НС на датасете MNIST.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

import sklearn.datasets as ds
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np

# %%
# Для начала сгенерируем датасет на 1000 элементов 

(data, labels) = ds.make_moons(n_samples=1000, noise=0.05)

pl.figure(figsize=(10, 5))

pl.scatter(data[:, 0], data[:, 1], c=labels, cmap=pl.cm.PuOr, lw=0, s=30)
plt.xlabel('X')
plt.ylabel('Y')

pl.show()

# %%
model = Sequential([
    Dense(8, input_shape=(2,), activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='softmax')
])


# For a binary classification problem
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(data, labels, epochs=50, verbose=1)
# По какой-то неясной причине. Если на выходе функция активации softmax, как указанно в задании, то точность всегда 0.5, что соответствует случайному совпадению.
# Попробуем с другой функцией.
# Out:
# Epoch 1/50
# ...
# 1000/1000 [==============================] - 0s 275us/step - loss: 7.9712 - acc: 0.5000
# Epoch 2/50
# ...
# 1000/1000 [==============================] - 0s 31us/step - loss: 7.9712 - acc: 0.5000
# Epoch 3/50
# ...
# 1000/1000 [==============================] - 0s 35us/step - loss: 7.9712 - acc: 0.5000
# Epoch 4/50
# ...
# 1000/1000 [==============================] - 0s 44us/step - loss: 7.9712 - acc: 0.5000
# Epoch 5/50
# ...
# 1000/1000 [==============================] - 0s 34us/step - loss: 7.9712 - acc: 0.5000
# Epoch 6/50
# ...
# 1000/1000 [==============================] - 0s 37us/step - loss: 7.9712 - acc: 0.5000
# Epoch 7/50
# ...
# 1000/1000 [==============================] - 0s 33us/step - loss: 7.9712 - acc: 0.5000
# Epoch 8/50
# ...
# 1000/1000 [==============================] - 0s 37us/step - loss: 7.9712 - acc: 0.5000
# Epoch 9/50
# ...
# 1000/1000 [==============================] - 0s 34us/step - loss: 7.9712 - acc: 0.5000
# Epoch 10/50
# ...

# %%
model = Sequential([
    Dense(8, input_shape=(2,), activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid') # Попробуем изменить функцию активации на выходе.
])


model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(data, labels, epochs=60, verbose=1)
# С функцией активации Sigmoid на выходе удаётся норально обучить модель.
# Out:
# Epoch 1/60
# ...
# 1000/1000 [==============================] - 0s 386us/step - loss: 0.6472 - acc: 0.6120
# Epoch 2/60
# ...
# 1000/1000 [==============================] - 0s 35us/step - loss: 0.5933 - acc: 0.6220
# Epoch 3/60
# ...
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.5510 - acc: 0.6580
# Epoch 4/60
# ...
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.5154 - acc: 0.7760
# Epoch 5/60
# ...
# 1000/1000 [==============================] - 0s 40us/step - loss: 0.4825 - acc: 0.8100
# Epoch 6/60
# ...
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.4504 - acc: 0.8170
# Epoch 7/60
# ...
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.4200 - acc: 0.8210
# Epoch 8/60
# ...
# 1000/1000 [==============================] - 0s 34us/step - loss: 0.3927 - acc: 0.8230
# Epoch 9/60
# ...
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.3697 - acc: 0.8320
# Epoch 10/60
# ...

# %%
# Визуализируем полученные результаты

def plot_model_results(decision, X, Y):
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    x, y = np.mgrid[x_min:x_max:.01, y_min:y_max:.01]
    pos = np.empty(x.shape + (2,))
    pos[:, :, 0] = x
    pos[:, :, 1] = y
    pos_lin = pos.reshape(pos.shape[0] * pos.shape[1], 2)
    pred_lin = decision(pos_lin)
    pred = pred_lin.reshape(pos.shape[0], pos.shape[1])

    fig, ax = plt.subplots()
    ax.set_xlim((x_min, x_max))
    ax.set_ylim((y_min, y_max))
    ax.contourf(x, y, pred, cmap='Reds', alpha=0.5)
    ax.contour(x, y, pred, levels=[0.5])

    colors = ['yellow' if y_i else 'blue' for y_i in Y]
    plt.scatter(X[:, 0], X[:, 1], c=colors)
    plt.show()

# %%
# Отлично. Модель обучена.
plot_model_results(model.predict, data, labels)

# %%
import mnist

# %%
from keras.layers import Flatten

elements_limit = 10000
train_values = mnist.train_images()[:elements_limit]
train_labels = mnist.train_labels()[:elements_limit]
test_values = mnist.train_images()[elements_limit:(elements_limit + 1000)]
test_labels = mnist.train_labels()[elements_limit:(elements_limit + 1000)]

# %%
mnist_model = Sequential([
    Dense(10, input_shape=(28, 28), activation='relu'),
    Dense(10, activation='relu'),
    Flatten(),
    Dense(10, activation='softmax')
])

mnist_model.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

mnist_model.fit(train_values, train_labels, epochs=70, verbose=1)
# Модель обучена
# Out:
# Epoch 1/70
# ...
# 10000/10000 [==============================] - 2s 195us/step - loss: 11.0233 - acc: 0.2945
# Epoch 2/70
# ...
# 10000/10000 [==============================] - 1s 55us/step - loss: 8.8205 - acc: 0.4357
# Epoch 3/70
# ...
# 10000/10000 [==============================] - 1s 56us/step - loss: 7.7128 - acc: 0.5075
# Epoch 4/70
# ...
# 10000/10000 [==============================] - 1s 54us/step - loss: 7.5191 - acc: 0.5205
# Epoch 5/70
# ...
# 10000/10000 [==============================] - 1s 54us/step - loss: 7.4141 - acc: 0.5292
# Epoch 6/70
# ...
# 10000/10000 [==============================] - 1s 55us/step - loss: 7.3342 - acc: 0.5344
# Epoch 7/70
# ...
# 10000/10000 [==============================] - 1s 55us/step - loss: 7.2425 - acc: 0.5402
# Epoch 8/70
# ...
# 10000/10000 [==============================] - 1s 70us/step - loss: 7.1691 - acc: 0.5459
# Epoch 9/70
# ...
# 10000/10000 [==============================] - 1s 63us/step - loss: 7.1346 - acc: 0.5482
# Epoch 10/70
# ...

# %%
# Провеврим точность обученной модели
import sklearn.metrics as smt

def calculate_accuracy(test, pred):
    accuracy = smt.adjusted_rand_score(test, pred)
    print('accuracy {0}'.format(accuracy))
    return

# %%
pred_labels = mnist_model.predict_classes(test_values)

calculate_accuracy(test_labels, pred_labels)
# Точность всего 80%, возможно модель переобучена.
# Попробуем обучить заново и проверить после обучения снова, при меньшем значении acc при обучении.
# Out:
# accuracy 0.8200715193695434

# %%
mnist_model = Sequential([
    Dense(10, input_shape=(28, 28), activation='relu'),
    Dense(10, activation='relu'),
    Flatten(),
    Dense(10, activation='softmax')
])

mnist_model.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

mnist_model.fit(train_values, train_labels, epochs=60, verbose=1)
# Out:
# Epoch 1/60
# ...
# 10000/10000 [==============================] - 2s 216us/step - loss: 9.5984 - acc: 0.3709
# Epoch 2/60
# ...
# 10000/10000 [==============================] - 1s 54us/step - loss: 7.0678 - acc: 0.5375
# Epoch 3/60
# ...
# 10000/10000 [==============================] - 1s 54us/step - loss: 6.3343 - acc: 0.5857
# Epoch 4/60
# ...
# 10000/10000 [==============================] - 1s 52us/step - loss: 6.0563 - acc: 0.6076
# Epoch 5/60
# ...
# 10000/10000 [==============================] - 1s 54us/step - loss: 5.8758 - acc: 0.6189
# Epoch 6/60
# ...
# 10000/10000 [==============================] - 1s 53us/step - loss: 5.7496 - acc: 0.6264
# Epoch 7/60
# ...
# 10000/10000 [==============================] - 1s 52us/step - loss: 5.6531 - acc: 0.6348
# Epoch 8/60
# ...
# 10000/10000 [==============================] - 1s 53us/step - loss: 5.6036 - acc: 0.6357
# Epoch 9/60
# ...
# 10000/10000 [==============================] - 1s 56us/step - loss: 5.5424 - acc: 0.6405
# Epoch 10/60
# ...

# %%
pred_labels = mnist_model.predict_classes(test_values)

calculate_accuracy(test_labels, pred_labels)
# Сюда это не вошло, прогонял несколько раз при меньшем acc, точность была ниже. 
# Решил прогнать на большем количестве эпох. Как видно - точность не сильно увеличилась. Попробуем обучить дата сет на большем количестве данных.
# Out:
# accuracy 0.8246151582962886

# %%
# Весь дата сет состоит из 60000 записей. Возьмём из них 50000, протестируем классификацию на 5000

elements_limit = 50000
test_limit = 5000

train_values = mnist.train_images()[:elements_limit]
train_labels = mnist.train_labels()[:elements_limit]
test_values = mnist.train_images()[elements_limit:(elements_limit + test_limit)]
test_labels = mnist.train_labels()[elements_limit:(elements_limit + test_limit)]

# %%
mnist_model = Sequential([
    Dense(10, input_shape=(28, 28), activation='relu'),
    Dense(10, activation='relu'),
    Flatten(),
    Dense(10, activation='softmax')
])

mnist_model.compile(optimizer='adam',
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

mnist_model.fit(train_values, train_labels, epochs=30, verbose=1)
# Out:
# Epoch 1/30
# ...
# 50000/50000 [==============================] - 5s 94us/step - loss: 6.4335 - acc: 0.5656
# Epoch 2/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 4.2254 - acc: 0.6967
# Epoch 3/30
# ...
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.7958 - acc: 0.8639
# Epoch 4/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.2944 - acc: 0.9138
# Epoch 5/30
# ...
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.2410 - acc: 0.9275
# Epoch 6/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.2184 - acc: 0.9346
# Epoch 7/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.2052 - acc: 0.9378
# Epoch 8/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.1942 - acc: 0.9410
# Epoch 9/30
# ...
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.1832 - acc: 0.9450
# Epoch 10/30
# ...

# %%
pred_labels = mnist_model.predict_classes(test_values)

calculate_accuracy(test_labels, pred_labels)
# Точность удалось увеличить до 90% Результат отличный. Задание можно считать выполненным.
# Out:
# accuracy 0.898987255545217

# %%
# Попробуем докрутить модель. Улучшим оптимизатор и увеличить количество эпох.
import keras

mnist_model = Sequential([
    Dense(20, input_shape=(28, 28), activation='relu'),
    Dense(20, activation='relu'),
    Flatten(),
    Dense(10, activation='softmax')
])

mnist_model.compile(optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

mnist_model.fit(train_values, train_labels, epochs=60, verbose=1)
# Out:
# Epoch 1/60
# ...
# 50000/50000 [==============================] - 6s 123us/step - loss: 5.5869 - acc: 0.6332
# Epoch 2/60
# ...
# 50000/50000 [==============================] - 4s 79us/step - loss: 3.8898 - acc: 0.7452
# Epoch 3/60
# ...
# 50000/50000 [==============================] - 4s 77us/step - loss: 3.7074 - acc: 0.7563
# Epoch 4/60
# ...
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.9927 - acc: 0.8487
# Epoch 5/60
# ...
# 50000/50000 [==============================] - 4s 77us/step - loss: 0.2865 - acc: 0.9341
# Epoch 6/60
# ...
# 50000/50000 [==============================] - 4s 75us/step - loss: 0.2021 - acc: 0.9445
# Epoch 7/60
# ...
# 50000/50000 [==============================] - 4s 76us/step - loss: 0.1807 - acc: 0.9485
# Epoch 8/60
# ...
# 19456/50000 [==========>...................] - ETA: 2s - loss: 0.1678 - acc: 0.9526
# ...
# ...
# 50000/50000 [==============================] - 4s 77us/step - loss: 0.0876 - acc: 0.9727
# Epoch 59/60
# ...

# %%
pred_labels = mnist_model.predict_classes(test_values)

calculate_accuracy(test_labels, pred_labels)
# Это было долго. Но результат аналогичный. Тем не менее задание считаю выполненным.
# Out:
# accuracy 0.9014379931344805
